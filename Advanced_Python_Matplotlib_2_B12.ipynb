# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
1.reading the file....

# %%
df=pd.read_csv('countries.csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
compare the population of china and US

# %%
us=df[df.country=='United States']
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
df.country=='United States'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
china=df[df.country=='China']
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year,us.population)
plt.show()

# %%
plt.plot(china.year,china.population)
plt.show()

# %%
plt.plot(china.year,china.population/10**6)# 10**6=Million
plt.show()

# %%
5 Countries graph: you have to submit as your activity:

# %%
canada=df [df.country=='Canada']
canada
# Out:
#     country  year  population
# 240  Canada  1952    14785584
# 241  Canada  1957    17010154
# 242  Canada  1962    18985849
# 243  Canada  1967    20819767
# 244  Canada  1972    22284500
# 245  Canada  1977    23796400
# 246  Canada  1982    25201900
# 247  Canada  1987    26549700
# 248  Canada  1992    28523502
# 249  Canada  1997    30305843
# 250  Canada  2002    31902268
# 251  Canada  2007    33390141

# %%
plt.plot(canada.year,canada.population/10**6)
plt.show()

# %%
india=df [df.country=='India']
india
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
plt.plot(india.year,india.population/10**6)
plt.show()

# %%
indons=df [df.country=='Indonesia']
indons
# Out:
#        country  year  population
# 708  Indonesia  1952    82052000
# 709  Indonesia  1957    90124000
# 710  Indonesia  1962    99028000
# 711  Indonesia  1967   109343000
# 712  Indonesia  1972   121282000
# 713  Indonesia  1977   136725000
# 714  Indonesia  1982   153343000
# 715  Indonesia  1987   169276000
# 716  Indonesia  1992   184816000
# 717  Indonesia  1997   199278000
# 718  Indonesia  2002   211060000
# 719  Indonesia  2007   223547000

# %%
plt.plot(indons.year,indons.population/10**6)
plt.show()

# %%
comoros=df [df.country=='Comoros']
comoros
# Out:
#      country  year  population
# 312  Comoros  1952      153936
# 313  Comoros  1957      170928
# 314  Comoros  1962      191689
# 315  Comoros  1967      217378
# 316  Comoros  1972      250027
# 317  Comoros  1977      304739
# 318  Comoros  1982      348643
# 319  Comoros  1987      395114
# 320  Comoros  1992      454429
# 321  Comoros  1997      527982
# 322  Comoros  2002      614382
# 323  Comoros  2007      710960

# %%
plt.plot(comoros.year,comoros.population)
plt.show()

# %%
aussie=df [df.country=='Australia']
aussie
# Out:
#       country  year  population
# 60  Australia  1952     8691212
# 61  Australia  1957     9712569
# 62  Australia  1962    10794968
# 63  Australia  1967    11872264
# 64  Australia  1972    13177000
# 65  Australia  1977    14074100
# 66  Australia  1982    15184200
# 67  Australia  1987    16257249
# 68  Australia  1992    17481977
# 69  Australia  1997    18565243
# 70  Australia  2002    19546792
# 71  Australia  2007    20434176

# %%
plt.plot(aussie.year,aussie.population/10**6)
plt.show()

# %%
cotediv =df[df.country =="Cote d'Ivoire"]
cotediv
# Out:
#            country  year  population
# 360  Cote d'Ivoire  1952     2977019
# 361  Cote d'Ivoire  1957     3300000
# 362  Cote d'Ivoire  1962     3832408
# 363  Cote d'Ivoire  1967     4744870
# 364  Cote d'Ivoire  1972     6071696
# 365  Cote d'Ivoire  1977     7459574
# 366  Cote d'Ivoire  1982     9025951
# 367  Cote d'Ivoire  1987    10761098
# 368  Cote d'Ivoire  1992    12772596
# 369  Cote d'Ivoire  1997    14625967
# 370  Cote d'Ivoire  2002    16252726
# 371  Cote d'Ivoire  2007    18013409

# %%
plt.plot(cotediv.year,cotediv.population/10**6)
plt.title('Population by Year')
plt.show()
